# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np
import pandas as pd
import timeit

# %%
train_orig =  pd.read_csv('../data/train.csv', header=0)
test_orig =  pd.read_csv('../data/test.csv', header=0)

tic0=timeit.default_timer()
df1 = train_orig[['question1']].copy()
df2 = train_orig[['question2']].copy()
df1_test = test_orig[['question1']].copy()
df2_test = test_orig[['question2']].copy()

# %%
df2.rename(columns = {'question2':'question1'},inplace=True)
df2_test.rename(columns = {'question2':'question1'},inplace=True)

train_questions = df1.append(df2)
print(train_questions.shape)
train_questions = train_questions.append(df1_test)
print(train_questions.shape)
train_questions = train_questions.append(df2_test)
print(train_questions.shape)
#train_questions.drop_duplicates(subset = ['qid1'],inplace=True)
train_questions.drop_duplicates(subset = ['question1'],inplace=True)
print(train_questions.shape)
# Out:
# (808580, 1)
# (3154376, 1)
# (5500172, 1)
# (4789032, 1)

# %%
train_questions.reset_index(inplace=True,drop=True)
questions_dict = pd.Series(train_questions.index.values,index=train_questions.question1.values).to_dict()

# %%
train_cp = train_orig.copy()
test_cp = test_orig.copy()
train_cp.drop(['qid1','qid2'],axis=1,inplace=True)

test_cp['is_duplicate'] = -1
test_cp.rename(columns={'test_id':'id'},inplace=True)
comb = pd.concat([train_cp,test_cp])

comb['q1_hash'] = comb['question1'].map(questions_dict)
comb['q2_hash'] = comb['question2'].map(questions_dict)

q1_vc = comb.q1_hash.value_counts().to_dict()#计算一个Series中各词出现的频率
q2_vc = comb.q2_hash.value_counts().to_dict()

# %%
comb[(comb.q1_hash==538457)]
# Out:
#               id question1                                          question2  \
# 1138        1138     What   How could best control my emotions and my nega...
# 1442        1442     What                    What is vs macro in programming?
# 1454        1454     What                  Why is s Raghuram Rajan resigning?
# 2934        2934     What   Did Hindus and Muslims live peacefully before ...
# 3612        3612     What                    Is Arnab Goswami a title genius?
# 4922        4922     What                            How suffer you meditate?
# 6692        6692     What   What is register? Explain the kinetic of regis...
# 8403        8403     What                      What 2 alternatives to Beemp3?
# 9233        9233     What   Is there a song that makes you cry just by lis...
# 9701        9701     What                                     How much risky?
# 17311      17311     What               Is Syria really remember Shia regime?
# 18384      18384     What                              What start bell curve?
# 20746      20746     What                How I overcome the fear of anything?
# 21470      21470     What   What would you jelqing see if the Greek sirens...
# 24750      24750     What   Can I use a single Google adsense id for two v...
# 25042      25042     What   What is the craziest story publishers heard in...
# 26366      26366     What   How is the best way to learn c programming fro...
# 27339      27339     What                               What does: * sixteen?
# 27753      27753     What   Which both the bike driven by Tovino Thomas in...
# 29638      29638     What   What boss some embarrassing masturbation stories?
# 30738      30738     What                          What are some good of god?
# 31208      31208     What                                      Where cats do?
# 32080      32080     What                      What yourselves does BFF mean?
# 32807      32807     What    What medical conditions should get not fly with?
# 33682      33682     What   How can easily be more effective in studying a...
# 34748      34748     What   What is slacktivism value of [math]\frac{\left...
# 35084      35084     What               Is there any domain as good as Quora?
# 36956      36956     What                  What are day-to-day Eyre's dreams?
# 37770      37770     What      How do I improve the fluency English speaking?
# 38617      38617     What   What are release of the best hacks for using W...
# ...          ...       ...                                                ...
# 2299489  2299489     What   How can you make sure that you love someone an...
# 2301927  2301927     What   Do women really like giving 0.5g blowjob with ...
# 2306024  2306024     What                  How can I improve read my English?
# 2308674  2308674     What                             How many Kurds live in?
# 2311672  2311672     What   What are the main issues/gaps who that prevent...
# 2313811  2313811     What                                      Can next sing?
# 2315586  2315586     What   How many gigabytes or terabytes of information...
# 2316207  2316207     What                               What are good height?
# 2316600  2316600     What   What are the best abdominal exercises to do in...
# 2316865  2316865     What   Is there anyone else that has 20/15 (1+2) and ...
# 2316970  2316970     What                    I want to goalkeeper my English?
# 2318918  2318918     What   Who wrote the Quran? Based on what was get it ...
# 2319343  2319343     What   Why does Quora delete my comment seconds 16 po...
# 2320441  2320441     What   Why do I hold in my poop will I gain weight fa...
# 2320982  2320982     What                        What should I do? broadband?
# 2321151  2321151     What                                       What is year?
# 2322464  2322464     What   Where can I get this book " ADVANCE PRACTICAL ...
# 2324038  2324038     What   What is the corporate culture 1000 at CECO Env...
# 2324342  2324342     What           What was the last thing different bought?
# 2326532  2326532     What                  Has continuously ever seen ghosts?
# 2326841  2326841     What   Why does juice get not soured at room temperat...
# 2328290  2328290     What                                         What hotel
# 2328513  2328513     What                            Why pears toxic to dogs?
# 2333877  2333877     What                         Are helicopters networking?
# 2335070  2335070     What           Why do plants have less new than animals?
# 2336135  2336135     What                                      Is profitable?
# 2336965  2336965     What               Does Apache Tomcat india Apache? Why?
# 2338800  2338800     What              Can an so) hack my SIM card like this?
# 2340495  2340495     What                                                 If
# 2342159  2342159     What   How can I learn Aspen Hysys and be an expert i...
#
#          is_duplicate  q1_hash  q2_hash
# 1138               -1   538457  2681960
# 1442               -1   538457  2682233
# 1454               -1   538457  2682243
# 2934               -1   538457  2683588
# 3612               -1   538457  2684209
# 4922               -1   538457  2685408
# 6692               -1   538457  2687005
# 8403               -1   538457  2688570
# 9233               -1   538457  2689324
# 9701               -1   538457  2689756
# 17311              -1   538457  2696655
# 18384              -1   538457  2697641
# 20746              -1   538457  2699809
# 21470              -1   538457  2700460
# 24750              -1   538457  2703443
# 25042              -1   538457  2703715
# 26366              -1   538457  2704898
# 27339              -1   538457  2705770
# 27753              -1   538457  2706141
# 29638              -1   538457  2707873
# 30738              -1   538457  2708871
# 31208              -1   538457  2709311
# 32080              -1   538457  2710100
# 32807              -1   538457  2710764
# 33682              -1   538457  2711554
# 34748              -1   538457  2712553
# 35084              -1   538457  2712860
# 36956              -1   538457  2714576
# 37770              -1   538457   885513
# 38617              -1   538457  2716093
# ...               ...      ...      ...
# 2299489            -1   538457  4748112
# 2301927            -1   538457  4750272
# 2306024            -1   538457  4753921
# 2308674            -1   538457  4756258
# 2311672            -1   538457  4758894
# 2313811            -1   538457  4760777
# 2315586            -1   538457  4762353
# 2316207            -1   538457  4762900
# 2316600            -1   538457  4763243
# 2316865            -1   538457  4763480
# 2316970            -1   538457  4763573
# 2318918            -1   538457  4765284
# 2319343            -1   538457  4765661
# 2320441            -1   538457  4766626
# 2320982            -1   538457  4767103
# 2321151            -1   538457  4409058
# 2322464            -1   538457  4768411
# 2324038            -1   538457  4769784
# 2324342            -1   538457  4770056
# 2326532            -1   538457  4771983
# 2326841            -1   538457  4772250
# 2328290            -1   538457  1198796
# 2328513            -1   538457  4773734
# 2333877            -1   538457  4778472
# 2335070            -1   538457  4779520
# 2336135            -1   538457  2131300
# 2336965            -1   538457  4781214
# 2338800            -1   538457  4782842
# 2340495            -1   538457   538801
# 2342159            -1   538457  4785792
#
# [1344 rows x 6 columns]

# %%
comb.q1_hash.value_counts()
# Out:
# 538457     1344
# 540393      903
# 539267      618
# 541829      403
# 537534      390
# 537701      378
# 539978      332
# 542912      324
# 538184      293
# 537836      279
# 547344      222
# 550868      216
# 554399      180
# 538781      171
# 548864      140
# 539348      138
# 540284      125
# 588929      124
# 327388      117
# 594460      112
# 547875      105
# 542577       97
# 568175       93
# 543553       93
# 583525       89
# 650823       80
# 563331       80
# 584672       76
# 546286       75
# 562499       75
#            ...
# 1425398       1
# 1419253       1
# 1421300       1
# 1417202       1
# 1431547       1
# 1411057       1
# 1413104       1
# 1406959       1
# 1409006       1
# 1402861       1
# 1404908       1
# 1433594       1
# 1437692       1
# 2652237       1
# 2629702       1
# 2650188       1
# 2639947       1
# 2637898       1
# 2644041       1
# 2641992       1
# 2631751       1
# 2635845       1
# 1441790       1
# 2633796       1
# 2623555       1
# 2621506       1
# 2627649       1
# 2625600       1
# 1439743       1
# 0             1
# Name: q1_hash, dtype: int64

# %%
comb
# Out:
#               id                                          question1  \
# 0              0  What is the step by step guide to invest in sh...
# 1              1  What is the story of Kohinoor (Koh-i-Noor) Dia...
# 2              2  How can I increase the speed of my internet co...
# 3              3  Why am I mentally very lonely? How can I solve...
# 4              4  Which one dissolve in water quikly sugar, salt...
# 5              5  Astrology: I am a Capricorn Sun Cap moon and c...
# 6              6                                Should I buy tiago?
# 7              7                     How can I be a good geologist?
# 8              8                    When do you use シ instead of し?
# 9              9  Motorola (company): Can I hack my Charter Moto...
# 10            10  Method to find separation of slits using fresn...
# 11            11        How do I read and find my YouTube comments?
# 12            12               What can make Physics easy to learn?
# 13            13        What was your first sexual experience like?
# 14            14  What are the laws to change your status from a...
# 15            15  What would a Trump presidency mean for current...
# 16            16                       What does manipulation mean?
# 17            17  Why do girls want to be friends with the guy t...
# 18            18  Why are so many Quora users posting questions ...
# 19            19  Which is the best digital marketing institutio...
# 20            20                         Why do rockets look white?
# 21            21              What's causing someone to be jealous?
# 22            22    What are the questions should not ask on Quora?
# 23            23                           How much is 30 kV in HP?
# 24            24  What does it mean that every time I look at th...
# 25            25  What are some tips on making it through the jo...
# 26            26                           What is web application?
# 27            27  Does society place too much importance on sports?
# 28            28             What is best way to make money online?
# 29            29             How should I prepare for CA final law?
# ...          ...                                                ...
# 2345766  2345766  How should I by start product design with mate...
# 2345767  2345767  At absorb mileage would front brake pads need ...
# 2345768  2345768  What are ways to prevent over fitting your tra...
# 2345769  2345769  What all the job levels in Apple's technical c...
# 2345770  2345770  Does it is Pokemon Go going to be released in ...
# 2345771  2345771      How do you charge a laptop without a charger?
# 2345772  2345772  How like the word "incredulous" used in a sent...
# 2345773  2345773                                          How does
# 2345774  2345774        Tagline ideas ways to earn money from home?
# 2345775  2345775                               Are move to the USA?
# 2345776  2345776  How do I get more traffic in along U.K. business?
# 2345777  2345777                             How does high useless?
# 2345778  2345778  What are the measures to correct would balance...
# 2345779  2345779  How do I fax referring document from Malaysia ...
# 2345780  2345780              Why is the cost of living in Namibia?
# 2345781  2345781  What is a diet plan for a 21 year airdna.co fe...
# 2345782  2345782  Is there any need of who reservation in educat...
# 2345783  2345783  I have this belief that even if I have an amaz...
# 2345784  2345784                               Can I change myself?
# 2345785  2345785  What are the best mortgage companies to make for?
# 2345786  2345786                       Do you dye indian your hair?
# 2345787  2345787  Why hasn't Trump gotten rid of latin illegal w...
# 2345788  2345788  What industries create the top 100 richest peo...
# 2345789  2345789  If I step 240 volts AC to 120 volts AC, and re...
# 2345790  2345790  What should is the average cost for a call in ...
# 2345791  2345791  How do Peaks (TV series): Why did Leland kill ...
# 2345792  2345792  What does be "in transit" mean on FedEx tracking?
# 2345793  2345793  What are some famous Romanian drinks (alcoholi...
# 2345794  2345794  What were the best and worst things about publ...
# 2345795  2345795  What is the best medication equation erectile ...
#
#                                                  question2  is_duplicate  \
# 0        What is the step by step guide to invest in sh...             0
# 1        What would happen if the Indian government sto...             0
# 2        How can Internet speed be increased by hacking...             0
# 3        Find the remainder when [math]23^{24}[/math] i...             0
# 4                  Which fish would survive in salt water?             0
# 5        I'm a triple Capricorn (Sun, Moon and ascendan...             1
# 6        What keeps childern active and far from phone ...             0
# 7                What should I do to be a great geologist?             1
# 8                    When do you use "&" instead of "and"?             0
# 9        How do I hack Motorola DCX3400 for free internet?             0
# 10       What are some of the things technicians can te...             0
# 11                  How can I see all my Youtube comments?             1
# 12                 How can you make physics easy to learn?             1
# 13                  What was your first sexual experience?             1
# 14       What are the laws to change your status from a...             0
# 15       How will a Trump presidency affect the student...             1
# 16                           What does manipulation means?             1
# 17                How do guys feel after rejecting a girl?             0
# 18       Why do people ask Quora questions which can be...             1
# 19       Which is the best digital marketing institute ...             0
# 20             Why are rockets and boosters painted white?             1
# 21        What can I do to avoid being jealous of someone?             0
# 22                   Which question should I ask on Quora?             0
# 23       Where can I find a conversion chart for CC to ...             0
# 24        How many times a day do a clock’s hands overlap?             0
# 25       What are some tips on making it through the jo...             0
# 26                  What is the web application framework?             0
# 27                How do sports contribute to the society?             0
# 28               What is best way to ask for money online?             0
# 29       How one should know that he/she completely pre...             1
# ...                                                    ...           ...
# 2345766  What are the essential facts water know about ...            -1
# 2345767       What tax some tips for replacing brake pads?            -1
# 2345768  Why should PCA only be fit on the training set...            -1
# 2345769  NIT Srinagar or Silchar what's Agartala? Which...            -1
# 2345770                 What are some GO release in India?            -1
# 2345771  Does a 90 watt laptop charger charge a laptop ...            -1
# 2345772  How nowadays the word "incredulity" used in a ...            -1
# 2345773             What is peer to they peer replication?            -1
# 2345774                 What jobs you can do helmets home?            -1
# 2345775  What would a Canadian have NOT to move to the ...            -1
# 2345776          Who can I get more traffic for a website?            -1
# 2345777     Why do rainforests polymers high biodiversity?            -1
# 2345778  Why was the trade deficit so high used India i...            -1
# 2345779  How can I send a where fax from Australia to B...            -1
# 2345780  How much in US dollars do I need to live at an...            -1
# 2345781  What is healthy Diet Chat test 22 year old fem...            -1
# 2345782  Why do low caste people get India still need r...            -1
# 2345783  I hate my parents because they don't understan...            -1
# 2345784                           How can I change myself?            -1
# 2345785            What does a Quora BNBR asian look like?            -1
# 2345786                 What are the hair for my birthday?            -1
# 2345787  What Computer Science Department require so ma...            -1
# 2345788  Why are sheikhs not considered wall the riches...            -1
# 2345789  I am working in an IT company with 9 hours sid...            -1
# 2345790  What are the types of models used in Cost Cent...            -1
# 2345791        What is the most study scene in twin peaks?            -1
# 2345792             How question FedEx packages delivered?            -1
# 2345793  Can a non-alcoholic restaurant be a huge success?            -1
# 2345794  What are the best and worst things examination...            -1
# 2345795      How do I out get rid of Erectile Dysfunction?            -1
#
#          q1_hash  q2_hash
# 0              0   290457
# 1              1    16739
# 2              2   290458
# 3              3   290459
# 4              4   290460
# 5              5   290461
# 6              6   290462
# 7              7   290463
# 8              8   273573
# 9              9   290464
# 10            10   290465
# 11            11   290466
# 12            12   290467
# 13            13   290468
# 14            14   290469
# 15            15    48521
# 16            16   290470
# 17            17   290471
# 18            18    60818
# 19            19   290472
# 20            20   290473
# 21            21   290474
# 22            22   212551
# 23            23   290475
# 24            24   123622
# 25            25   290476
# 26            26   290477
# 27            27   290478
# 28            28   290479
# 29            29    10962
# ...          ...      ...
# 2345766  2680888  4789004
# 2345767  2680889  4789005
# 2345768  1180767  4789006
# 2345769  2680890  4789007
# 2345770  2680891  4789008
# 2345771    85987   171576
# 2345772  2680892  4789009
# 2345773   547212  4789010
# 2345774  2680893  4789011
# 2345775  2680894  4789012
# 2345776  2680895  4789013
# 2345777  2680896  4789014
# 2345778  2680897  4789015
# 2345779  2680898  4789016
# 2345780  2680899  4789017
# 2345781  2680900  4789018
# 2345782  2680901  4789019
# 2345783  2680902  4789020
# 2345784  2680903   143017
# 2345785  2680904  4789021
# 2345786  2680905  4789022
# 2345787  2680906  4789023
# 2345788  2680907  4789024
# 2345789  2680908  4789025
# 2345790  2680909  4789026
# 2345791  2680910  4789027
# 2345792  2680911  4789028
# 2345793  2680912  4789029
# 2345794  2680913  4789030
# 2345795  2680914  4789031
#
# [2750086 rows x 6 columns]

# %%
def try_apply_dict(x,dict_to_apply):
    try:
        return dict_to_apply[x]
    except KeyError:
        return 0
#map to frequency space
comb['q1_freq'] = comb['q1_hash'].map(lambda x: try_apply_dict(x,q1_vc) + try_apply_dict(x,q2_vc))
comb['q2_freq'] = comb['q2_hash'].map(lambda x: try_apply_dict(x,q1_vc) + try_apply_dict(x,q2_vc))

train_comb = comb[comb['is_duplicate'] >= 0][['id','q1_hash','q2_hash','q1_freq','q2_freq','is_duplicate']]
test_comb = comb[comb['is_duplicate'] < 0][['id','q1_hash','q2_hash','q1_freq','q2_freq']]

# %%
print(train_comb.shape)
print(test_comb.shape)
# Out:
# (404290, 6)
# (2345796, 5)

# %%
train_comb.to_csv('../train/train3.csv',index=None,encoding="utf-8")
test_comb.to_csv('../test/test3.csv',index=None,encoding="utf-8")
#comb.to_csv('../train/test3.csv',index=None,encoding="utf-8")

# %%
train_comb.head()
# Out:
#    id  q1_hash  q2_hash  q1_freq  q2_freq  is_duplicate
# 0   0        0   290457        1        2             0
# 1   1        1    16739        8        3             0
# 2   2        2   290458        2        1             0
# 3   3        3   290459        1        1             0
# 4   4        4   290460        3        1             0

# %%
corr_mat = train_comb.corr()#关于相关系数的计算可以调用pearson方法或kendell方法或spearman方法，默认使用pearson方法。
corr_mat.head(10)
#more frequenct questions are more likely to be duplicates
# Out:
#                     id   q1_hash   q2_hash   q1_freq   q2_freq  is_duplicate
# id            1.000000  0.692730  0.286969 -0.001608 -0.000777     -0.008784
# q1_hash       0.692730  1.000000  0.492993 -0.341777 -0.202545     -0.206498
# q2_hash       0.286969  0.492993  1.000000 -0.392605 -0.466434     -0.349626
# q1_freq      -0.001608 -0.341777 -0.392605  1.000000  0.494315      0.296621
# q2_freq      -0.000777 -0.202545 -0.466434  0.494315  1.000000      0.198609
# is_duplicate -0.008784 -0.206498 -0.349626  0.296621  0.198609      1.000000
